# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()

model = ChatOpenAI()

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': "I. Introduction\n    A. Introduce the topic of Artificial Intelligence (AI) and its growing significance in India\n    B. Provide some background information on AI and its applications\n    C. Preview the key points that will be covered in the blog\n    \nII. Overview of the current state of AI in India\n    A. Discuss the adoption of AI in various industries in India\n    B. Highlight some notable AI startups and companies in India\n    C. Showcase the government's initiatives to promote AI technology in the country\n    \nIII. Factors contributing to the rise of AI in India\n    A. Availability of talent and skilled workforce in the field of AI\n    B. Increasing investments in AI research and development\n    C. Growing demand for AI solutions in various sectors such as healthcare, finance, and agriculture\n    \nIV. Challenges and opportunities in the AI landscape in India\n    A. Discuss the challenges faced by AI technology in India, such as data privacy concerns and lack of regulatory frameworks\n    B. Explore the opportunities for growth and innovation in the AI sector in India\n    C. Highlight the potential impact of AI on the Indian economy and job market\n    \nV. Case studies of successful AI implementations in India\n    A. Showcase examples of AI applications in Indian businesses and organizations\n    B. Discuss the benefits and outcomes of these AI implementations\n    C. Analyze the lessons learned from these case studies\n    \nVI. Future trends and projections for AI in India\n    A. Predict the future growth and trajectory of AI technology in India\n    B. Discuss emerging trends and technologies in the field of AI\n    C. Provide recommendations for businesses and policymakers to capitalize on the AI opportunity\n    \nVII. Conclusion\n    A. Summarize the key points discussed in the blog\n    B. Reiterate the significance of the rise of AI in India\n    C. Encourage readers to stay informed and updated on developments in the AI landscape in India", 'content': "Artificial Intelligence (AI) has become one of the most transformative technologies in recent years, with its applications spanning across various industries such as healthcare, finance, agriculture, and more. In India, the rise of AI is evident as more and more businesses and organizations are embracing this technology to drive innovation and efficiency. In this blog, we will delve into the rise of AI in India, exploring the current state of AI, key factors contributing to its growth, challenges and opportunities, successful case studies, future trends, and projections.\n\nI. Introduction\n\nA. Introduce the topic of Artificial Intelligence (AI) and its growing significance in India\n\nAI refers to the simulation of human intelligence processes by machines, including learning, reasoning, and self-correction. In recent years, AI has gained prominence in India, with businesses and organizations increasingly leveraging AI to enhance their operations and decision-making processes.\n\nB. Provide some background information on AI and its applications\n\nAI applications range from chatbots and virtual assistants to predictive analytics and autonomous vehicles. These applications have the potential to revolutionize industries and bring about significant advancements in technology.\n\nC. Preview the key points that will be covered in the blog\n\nThis blog will explore the current state of AI in India, factors contributing to its rise, challenges and opportunities, successful case studies, future trends, and projections for the AI landscape in the country.\n\nII. Overview of the current state of AI in India\n\nA. Discuss the adoption of AI in various industries in India\n\nVarious industries in India, such as healthcare, finance, and agriculture, are increasingly adopting AI to streamline processes, improve customer experiences, and drive innovation.\n\nB. Highlight some notable AI startups and companies in Indi ...

# %%
print(final_state['outline'])
# Out:
# I. Introduction
#     A. Introduce the topic of Artificial Intelligence (AI) and its growing significance in India
#     B. Provide some background information on AI and its applications
#     C. Preview the key points that will be covered in the blog
#
# II. Overview of the current state of AI in India
#     A. Discuss the adoption of AI in various industries in India
#     B. Highlight some notable AI startups and companies in India
#     C. Showcase the government's initiatives to promote AI technology in the country
#
# III. Factors contributing to the rise of AI in India
#     A. Availability of talent and skilled workforce in the field of AI
#     B. Increasing investments in AI research and development
#     C. Growing demand for AI solutions in various sectors such as healthcare, finance, and agriculture
#
# IV. Challenges and opportunities in the AI landscape in India
#     A. Discuss the challenges faced by AI technology in India, such as data privacy concerns and lack of regulatory frameworks
#     B. Explore the opportunities for growth and innovation in the AI sector in India
#     C. Highlight the potential impact of AI on the Indian economy and job market
#
# V. Case studies of successful AI implementations in India
#     A. Showcase examples of AI applications in Indian businesses and organizations
#     B. Discuss the benefits and outcomes of these AI implementations
#     C. Analyze the lessons learned from these case studies
#
# VI. Future trends and projections for AI in India
#     A. Predict the future growth and trajectory of AI technology in India
#     B. Discuss emerging trends and technologies in the field of AI
#     C. Provide recommendations for businesses and policymakers to capitalize on the AI opportunity
#
# VII. Conclusion
#     A. Summarize the key points discussed in the blog
#     B. Reiterate the significance of the rise of AI in India
#     C. Encourage readers to stay informed and updated on developments in the AI landscape in India

# %%
print(final_state['content'])
# Out:
# Artificial Intelligence (AI) has become one of the most transformative technologies in recent years, with its applications spanning across various industries such as healthcare, finance, agriculture, and more. In India, the rise of AI is evident as more and more businesses and organizations are embracing this technology to drive innovation and efficiency. In this blog, we will delve into the rise of AI in India, exploring the current state of AI, key factors contributing to its growth, challenges and opportunities, successful case studies, future trends, and projections.
#
# I. Introduction
#
# A. Introduce the topic of Artificial Intelligence (AI) and its growing significance in India
#
# AI refers to the simulation of human intelligence processes by machines, including learning, reasoning, and self-correction. In recent years, AI has gained prominence in India, with businesses and organizations increasingly leveraging AI to enhance their operations and decision-making processes.
#
# B. Provide some background information on AI and its applications
#
# AI applications range from chatbots and virtual assistants to predictive analytics and autonomous vehicles. These applications have the potential to revolutionize industries and bring about significant advancements in technology.
#
# C. Preview the key points that will be covered in the blog
#
# This blog will explore the current state of AI in India, factors contributing to its rise, challenges and opportunities, successful case studies, future trends, and projections for the AI landscape in the country.
#
# II. Overview of the current state of AI in India
#
# A. Discuss the adoption of AI in various industries in India
#
# Various industries in India, such as healthcare, finance, and agriculture, are increasingly adopting AI to streamline processes, improve customer experiences, and drive innovation.
#
# B. Highlight some notable AI startups and companies in India
#
# India is home to several AI startups and companies that are at the forefront of AI innovation. Companies like Niki.ai, Haptik, and SigTuple are leading the way in developing AI solutions for businesses.
#
# C. Showcase the government's initiatives to promote AI technology in the country
#
# The Indian government has recognized the importance of AI and has launched initiatives to promote the development and adoption of AI technology. Programs like the National AI Portal and the National AI Strategy aim to create a conducive environment for AI growth in India.
#
# III. Factors contributing to the rise of AI in India
#
# A. Availability of talent and skilled workforce in the field of AI
#
# India has a strong talent pool in the field of AI, with a growing number of professionals specializing in areas such as machine learning, data science, and AI research.
#
# B. Increasing investments in AI research and development
#
# Investments in AI research and development have been on the rise in India, with businesses, academic institutions, and government agencies investing in AI to drive innovation and growth.
#
# C. Growing demand for AI solutions in various sectors
#
# The increasing demand for AI solutions in sectors such as healthcare, finance, and agriculture is driving the growth of AI technology in India. Businesses are realizing the potential of AI to improve processes, increase efficiency, and deliver better outcomes.
#
# IV. Challenges and opportunities in the AI landscape in India
#
# A. Discuss the challenges faced by AI technology in India
#
# AI technology in India is not without its challenges. Issues such as data privacy concerns, lack of regulatory frameworks, and ethical considerations pose challenges to the growth and adoption of AI in the country.
#
# B. Explore the opportunities for growth and innovation in the AI sector in India
#
# Despite the challenges, there are ample opportunities for growth and innovation in the AI sector in India. Businesses that leverage AI technology have the potential to gain a competitive edge and drive significant value for their organizations.
#
# C. Highlight the potential impact of AI on the Indian economy and job market
#
# AI has the potential to drive economic growth and create new job opportunities in India. The adoption of AI technology could lead to the creation of new roles and professions within the AI ecosystem.
#
# V. Case studies of successful AI implementations in India
#
# A. Showcase examples of AI applications in Indian businesses and organizations
#
# Examples of successful AI implementations in India include predictive analytics in finance, AI-powered diagnostics in healthcare, and smart farming in agriculture.
#
# B. Discuss the benefits and outcomes of these AI implementations
#
# AI implementations in Indian businesses and organizations have led to improved efficiency, increased cost savings, enhanced customer experiences, and better decision-making.
#
# C. Analyze the lessons learned from these case studies
#
# Lessons learned from successful AI implementations in India include the importance of data quality, continuous learning and improvement, and stakeholder engagement.
#
# VI. Future trends and projections for AI in India
#
# A. Predict the future growth and trajectory of AI technology in India
#
# The future of AI in India looks promising, with continued growth and development in the field. Businesses that embrace AI technology and invest in AI research and development are likely to stay ahead of the curve.
#
# B. Discuss emerging trends and technologies in the field of AI
#
# Emerging trends in AI include advancements in deep learning, natural language processing, and computer vision, which have the potential to revolutionize industries and create new opportunities for growth.
#
# C. Provide recommendations for businesses and policymakers to capitalize on the AI opportunity
#
# Businesses and policymakers in India should focus on building a data-driven culture, investing in AI talent and research, and creating regulatory frameworks that support the responsible and ethical use of AI technology.
#
# VII. Conclusion
#
# A. Summarize the key points discussed in the blog
#
# The rise of AI in India presents exciting opportunities for growth and innovation across industries. Businesses that embrace AI technology have the potential to drive significant value and create new opportunities for growth.
#
# B. Reiterate the significance of the rise of AI in India
#
# The rise of AI in India is shaping the future of technology and innovation in the country. Businesses, policymakers, and individuals need to stay informed and updated on developments in the AI landscape to capitalize on the opportunities that AI technology presents.
#
# C. Encourage readers to stay informed and updated on developments in the AI landscape in India
#
# As AI technology continues to evolve and grow in India, it is important for businesses and individuals to stay informed and updated on new trends, developments, and opportunities in the AI landscape. By staying informed, businesses and individuals can leverage AI technology to drive growth, innovation, and success in the future.
